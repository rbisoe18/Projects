# %%
import pandas
import requests
from bs4 import BeautifulSoup

for i in range(2,10):
    url  = "https://www.flipkart.com/search?q=mobile+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1"+str(i)
    r = requests.get(url)
    # print(r)                                                  # respose

    soup = BeautifulSoup(r.text, "lxml")                        # text from the html
    # print(soup)

    # while True:
    np = soup.find("a", class_ = "_1LKTO3").get("href")         # np - next page
    #print(np)

    cnp = "https://www.flipkart.com" + np                         # cnp - complete next page
    print(cnp)

    url = cnp
    r = requests.get(url)
    soup = BeautifulSoup(r.text,"lxml")

# %%
import pandas
import requests
from bs4 import BeautifulSoup

Product_name = []
Prices = []
Description = []
Reviews = []

url  = "https://www.flipkart.com/search?q=mobile+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1"+str(1)
r = requests.get(url)                              # respose 
                                                  
soup = BeautifulSoup(r.text, "lxml")              # text from the html

box = soup.find("div",class_ = "_1YokD2 _3Mn1Gg")

names = box.find_all("div",class_ = "_4rR01T")
# print(names)

for i in names:
    name = i.next
    Product_name.append(name)

# print(Product_name) 
# print("-----")
#print("len of product_name:",len(Product_name)) 

prices = box.find_all("div",class_ = "_30jeq3 _1_WHN1")
for i in prices:
    name = i.next
    Prices.append(name)
# print(Prices)
# print("len of Prices :",len(Prices))
# print("---")

desc = box.find_all("ul",class_ = "_1xgFaf")

for i in desc:
    name = i.next
    Description.append(name)
# print(Description)
# print("len of Description :",len(Description))
# print("-----")

reviews = box.find_all("div",class_ = "_3LWZlK")

for i in reviews:
    name = i.next
    Reviews.append(name)
# print(Reviews)
# print("len of Reviews :",len(Reviews)) # overall reviews on the page
# Out:
# ['SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)', 'Infinix Smart 6 HD (Force Black, 32 GB)', 'APPLE iPhone 14 (Blue, 256 GB)', 'Infinix Note 12 (Jewel Blue, 64 GB)', 'realme 9 (Sunburst Gold, 128 GB)', 'realme 9 (Stargaze White, 128 GB)', 'realme 9 (Meteor Black, 128 GB)', 'Infinix Note 12 (Force Black, 64 GB)', 'realme 9 5G (Stargaze White, 64 GB)', 'APPLE iPhone 14 ((PRODUCT)RED, 128 GB)', 'realme 9 5G (Meteor Black, 64 GB)', 'realme 9 5G (Supersonic Blue, 128 GB)', 'realme 9 5G (Meteor Black, 128 GB)', 'SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)', 'realme 9 5G (Supersonic Blue, 64 GB)', 'realme 9 5G (Supersonic Black, 64 GB)', 'APPLE iPhone 14 Plus ((PRODUCT)RED, 128 GB)', 'realme C25_Y (Metal Grey, 64 GB)', 'realme C25_Y (Glacier Blue, 64 GB)', 'SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)', 'POCO M4 Pro (Power Black, 128 GB)', 'REDMI Note 12 Pro+ 5G (Iceberg Blue, 256 GB)', 'APPLE iPhone 14 (Starlight, 256 GB)', 'MOTOROLA g42 (Metallic Rose, 64 GB)']
# -----
# ...

# %% [markdown]
# ---
# # df

# %%
import pandas
import requests
from bs4 import BeautifulSoup

Product_name = []
Prices = []
Description = []
Reviews = []

for i in range(2,12):
    url  = "https://www.flipkart.com/search?q=mobile+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1"+str(1)
    r = requests.get(url)                              # respose 

    soup = BeautifulSoup(r.text, "lxml")              # text from the html

    box = soup.find("div",class_ = "_1YokD2 _3Mn1Gg")

    names = box.find_all("div",class_ = "_4rR01T")

    for i in names:
        name = i.next
        Product_name.append(name)

    prices = box.find_all("div",class_ = "_30jeq3 _1_WHN1")
    for i in prices:
        name = i.next
        Prices.append(name)

    desc = box.find_all("ul",class_ = "_1xgFaf")

    for i in desc:
        name = i.next
        Description.append(name)

    reviews = box.find_all("div",class_ = "_3LWZlK")

    for i in reviews:
        name = i.next
        Reviews.append(name)

import pandas as pd
df = pd.DataFrame({"Product Name":Product_name,"Prices":Prices,"Description":Description,"Reviews":Reviews})

df.to_csv("flipkart_mobiles_under_50k.csv")

# %%
df
# Out:
#                                      Product Name   Prices  \
# 0                  APPLE iPhone 14 (Blue, 256 GB)  ₹76,999
# 1            vivo T1 5G (Starlight Black, 128 GB)  ₹15,990
# 2                    POCO C50 (Royal Blue, 32 GB)   ₹6,249
# 3                                    Salora Coral     ₹899
# 4         Infinix Smart 6 HD (Force Black, 32 GB)   ₹5,799
# ..                                            ...      ...
# 235  SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)  ₹13,999
# 236             POCO M4 Pro (Power Black, 128 GB)  ₹13,999
# 237  REDMI Note 12 Pro+ 5G (Iceberg Blue, 256 GB)  ₹29,999
# 238           APPLE iPhone 14 (Starlight, 256 GB)  ₹76,999
# 239           MOTOROLA g42 (Metallic Rose, 64 GB)  ₹10,999
#
#                                          Description Reviews
# 0                                       [256 GB ROM]     4.6
# 1     [4 GB RAM | 128 GB ROM | Expandable Upto 1 TB]     4.3
# 2    [2 GB RAM | 32 GB ROM | Expandable Upto 512 GB]     4.5
# ...
